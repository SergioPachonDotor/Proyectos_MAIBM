# %%
import Assembler as tmk
import numpy as np
import matplotlib.pyplot as plt


α1 = 1
α2 = 0.25

β1 = 0.0001
β2 = 0.0001

k1 = 500
k2 = 500

γ1 = 1/15
γ2 = 1/15

x1 = 400
x2 = 400

ε1 = 0.0005
ε2 = 0.0001

k_values = {
            'α1' : α1,
            'α2' : α2,
            'β1' : β1,
            'β2' : β2,
            'k1' : k1,
            'k2' : k2,
            'γ1' : γ1,
            'γ2' : γ2,
            'ε1' : ε1,
            'ε2' : ε2            
        }

propensities = {
                'R1'  : '(1 - (x1/k1)) * x1 * α1',
                'R2'  : 'x1 * x2 * β1',
                'R3'  : '(1 - (x2/k2)) * x2 * α2',
                'R4'  : 'x2 * x1 * β2',
                'R5'  : 'γ1 * x1',
                'R6'  : 'γ2 * x2',
                'R7'  : 'ε1 * z * x1',
                'R8'  : 'ε2 * z * x2',
            }

species = {
        'x1':    x1,
        'x2':    x2,
        'z' :    1500.
}

reactions = {

    'R1':  {'create' :  ['x1']},
    'R2':  {'destroy':  ['x1']},
    
    'R3':  {'create' :  ['x2']},
    'R4':  {'destroy':  ['x2']},
    
    'R5':  {'destroy':  ['x1']},
    'R6':  {'destroy':  ['x2']},
    
    'R7':  {'destroy':  ['x1', 'z']},
    'R8':  {'destroy':  ['x2', 'z']},
}

simulation_parameters = {
    'tmax': 100.,
    'sampling_time': 1.,
    'cells': 1000.
}
